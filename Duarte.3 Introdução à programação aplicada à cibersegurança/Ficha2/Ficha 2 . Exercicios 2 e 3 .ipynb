# %% [markdown]
# # Exercício 1 - listas
#
# Crie uma estrutura de repetição para fazer a leitura de 5 números inteiros e os armazene dentro de uma lista. Após a leitura, crie outra estrutura de repetição para somar todos os valores digitados

# %%
lista = []
for _ in range(1, 6):
  valor = int(input('Digite o valor: '))
  lista.append(valor)
# Out:
# Digite o valor: 2
# Digite o valor: 5
# Digite o valor: 6
# Digite o valor: 8
# Digite o valor: 9

# %%
lista
# Out:
# [2, 3, 4, 2, 6]

# %%
len(lista)
# Out:
# 5

# %%
soma = 0
for i in range(len(lista)):
  #print(lista[i])
  soma += lista[i]
print('Soma: ', soma)
# Out:
# Soma:  15

# %%
a = sum(lista)
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d1637e473eab> in <module>
# ----> 1 a = sum(lista)
#       2 print(a)
#
# NameError: name 'lista' is not defined

# %%
import numpy as np
np.array(lista).sum()
# Out:
# 30

# %% [markdown]
# # Exercícios 2 - dicionários
#
# Crie um dicionário para armazenar o nome e a nota de 3 alunos, fazendo a leitura dos valores por meio de uma estrutura de repetição. Depois, crie uma nova estrutura de repetição para somar todas as notas e retornar a média

# %%
alunos = {}
for _ in range(1, 4):
  nome = input('Digite o nome: ')
  nota = float(input('Digite a nota: '))
  alunos[nome] = nota
# Out:
# Digite o nome: Ana
# Digite a nota: 12
# Digite o nome: Carlos
# Digite a nota: 9
# Digite o nome: Rui
# Digite a nota: 8

# %%
alunos
# Out:
# {'Ana': 12.0, 'Carlos': 9.0, 'Rui': 8.0}

# %%
alunos['Carlos']
# Out:
# 9.0

# %%
alunos.values()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-1255a0883dd5> in <module>
# ----> 1 alunos.values()
#
# NameError: name 'alunos' is not defined

# %%
soma = 0
for nota in alunos.values():
  #print(nota)
  soma += nota
print('Média: ', soma / 3)
# Out:
# Média:  9.666666666666666

# %% [markdown]
# # Exercício 3: Matriz
#
# Dada a matriz abaixo, construa uma estrutura de repetição para percorrer e somar todos os elementos da matriz

# %%
matriz =np.array ([[3, 4, 1],
          [3, 1, 5]])
matriz
# Out:
# Running cells with 'd:\Programs\Python\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'd:/Programs/Python/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
matriz.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f79195dc031e> in <module>
# ----> 1 matriz.shape
#
# NameError: name 'matriz' is not defined

# %%
soma = 0
for i in range(matriz.shape[0]):
  for j in range(matriz.shape[1]):
    #print(matriz[i][j])
    soma += matriz[i][j]
print('Soma: ', soma)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4a1d9989e229> in <module>
#       1 soma = 0
# ----> 2 for i in range(matriz.shape[0]):
#       3   for j in range(matriz.shape[1]):
#       4     #print(matriz[i][j])
#       5     soma += matriz[i][j]
#
# NameError: name 'matriz' is not defined
